# %%
name = input("Type Your name: ")
print("Welcome",name,"You are assigned a Mission to stop a bank robbery")

answer= input("You are at the bank, Now you have to decide which door to choose, Front door or Back door, (type front or back to choose the door ) ").lower()

if answer == "back":
    
    print("Good, Nobody noticed you and you are inside the bank.")
    answer = input(" You see one of the robber gaurding the door, You kill him by gun or a knife. (Type gun or knife)").lower()
    
    if answer== "gun":
        print("Gun shot alerted the other robbers and they kill you.")
        
        print("")
        print("You lose.")
    
    elif answer == "knife":
        print("Excellent Job! You successfully killed the robber. You see two of the robber comming towards you \n")
        answer = input("You fight or You hide, ( Type fight or hide)\n ")
        print("")
        
        if answer == "fight":
            print("You were taken down, You lose ")
        elif answer == "hide":
            
            
            print("They did not noticed you \n")
            print("You killed the robbers from behind \n")
            print("You entered the locker room and find the robber is trying to crack open the vault \n")
            
            answer = input("You immediately SHOOTS him or You use knife to stab him,(Type shoot or stab) ").lower()
            
            if answer =="shoot":
                print("")
                print("CONGRATULATION!", name , "you stopped the robbery \n")
                
            elif answer == "stab":
                print("You missed to hit a critical spot and you were killed by the robber \n")
                print("You lose")
            else:
                print("Not a valid option. You lose.")
                
                
                
                
                
                
                
        else:
            
             print("Not a valid option. You lose.")
            
        
        
        
        
        
        
    else:
        print("Not a valid option. You lose.")
        
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
elif answer == "front":
    print("You are immediately SHOT DOWN")
    print("You lose")

else:
    print("Not a valid option. You lose.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2832\3093893334.py in <module>
# ----> 1 name = input("Type Your name: ")
#       2 print("Welcome",name,"You are assigned a Mission to stop a bank robbery")
#       3
#       4 answer= input("You are at the bank, Now you have to decide which door to choose, Front door or Back door, (type front or back to choose the door ) ").lower()
#       5
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ~\anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...
